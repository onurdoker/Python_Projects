# %% [markdown]
# ## House Price Statistical Analyzer
#
# Subject: Statistical calculations and NumPy/Pandas filtering
#
# Components: Pandas, NumPy, House Price Data (csv)
#
# Requirements:
# - Calculate mean, median and standard deviation values for all numerical columns
# - Filter records belonging to a specific region code using NumPy masks or Pandas loc function
# - Find the average house price on the selected region
# - Create a Matplotlib Scatter Plot to show the relationship between two variables

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading house price dataset
df = pd.read_csv('housing.csv')

# %%
# Calculate mean, median and standard derivation value
mean_values = df.mean(numeric_only=True)
median_values = df.median(numeric_only=True)
std_values = df.std(numeric_only=True)

print('Mean Values:')
print(mean_values)
print('\nMedian Values:')
print(median_values)
print('\nStandard Deviation Values:')
print(std_values)
# Out:
# Mean Values:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64
#
# Median Values:
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64
#
# Standard Deviation Values:
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %%
# Filter records belonging to a specific region code using NumPy masks or Pandas loc function
region_code = 4000
filtered_df = df.loc[df['area'] == region_code]

print(filtered_df.head())
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 70   6790000  4000         3          2        2      yes        no      yes
# 81   6615000  4000         3          2        2      yes        no      yes
# 239  4585000  4000         3          1        2      yes        no       no
# 256  4480000  4000         3          1        2      yes        no       no
# 294  4200000  4000         4          2        2       no        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 70               no             yes        0      yes   semi-furnished
# 81               no             yes        1       no   semi-furnished
# 239              no              no        1       no        furnished
# 256              no              no        2       no        furnished
# 294              no              no        0       no   semi-furnished

# %%
# Find the average house price on the selected region
print(f'The average house price in region {region_code} is {filtered_df['price'].mean():.2f}$')
# Out:
# The average house price in region 4000 is 4040272.73$

# %%
# Create a Matplotlib Scatter Plot to show the relationship between two variables
plt.figure(figsize=(10, 6))
plt.scatter(df['area'], df['price'])
plt.title(f'House Price vs Size')
plt.xlabel('House Size (sqft)')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()
